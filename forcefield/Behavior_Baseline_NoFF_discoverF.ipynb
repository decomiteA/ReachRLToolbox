# %% [markdown]
# ## Shooting movement - No FF - Discover = F

# %%
# %load_ext autoreload
# %autoreload 2

from ff_environment import TargetReach
from agents.agent import Agent
from collections import deque
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create and initialize the environment
env = TargetReach(space_padding=2, discover=False)

env_info = env.reset()

# %%
# Provide some information about the initial state and target position

action_size = env.action_size
print('Size of each action:', action_size)

# Examine the state space
state = env_info.state
state_size = len(state)
print('The agent observes a state with length: {}'.format(state_size))
print('The starting state looks like:',state)
# Out:
# Size of each action: 2
# The agent observes a state with length: 6
# The starting state looks like: [0.5 1.  0.  0.  0.  0. ]

# %%
# Instantiate the agent : 

agent = Agent(state_size, action_size, random_seed=2)

# %%
# Train the agent with ddpg
scores, trajectories, actions_tracker = agent.train_ddpg(env,n_episodes=3000,print_every=1000,stop=True)
# Out:
# Episode 0 	Average Reward: -1.12
# Episode 1000 	Average Reward: -0.33
# Episode 2000 	Average Reward: -0.64
# Episode 2999 	Average Reward: -0.95

# %%
# Plot handling

# Score per episode and behavior at the end of training
trajectories.plot_converged(legend=False)

# Positions and speeds for trial idx
trajectories.plot_kinematics(499) 

# Trajectory for trial idx
trajectories.plot(499,legend=False)
# Out:
# (<Figure size 432x288 with 1 Axes>, <AxesSubplot:>)
